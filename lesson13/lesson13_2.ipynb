# %%
import matplotlib.pyplot as plt

fig = plt.figure()

ax_1 = fig.add_subplot(1,1,1)

X = [0,1,2]
Y = [3,4,5]
ax_1.plot(X, Y, 'bo-.')

# %%
import matplotlib.pyplot as plt
pic = plt.figure()
ax_1 = pic.add_subplot(1, 3, 1)
ax_2 = pic.add_subplot(1, 3, 2) 
ax_3 = pic.add_subplot(1, 3, 3)

ax_1.set_title("1")
ax_2.set_title("2")
ax_3.set_title("3")
# Out:
# Text(0.5, 1.0, '3')

# %%
import matplotlib.pyplot as plt
student1:dict[str,int] = {"chinese":75,"english":80,"math":90,"history":85,"discover":76}
student2:dict[str,int] = {"chinese":74,"english":90,"math":91,"history":86,"discover":60}
subject = list(student1.keys())
scorel = list(student1.values())
score2 = list(student2.values())

figure = plt.figure(figsize=(10,5))
axes = figure.add_subplot(1,1,1)
axes.plot(subject,scorel)
axes.plot(subject,score2)

# %%
#window字型路徑
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#=======
#mac字型路徑
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#=======
#linux
#安裝字型
#sudo apt-get update -y
#sudo apt-get install -y fonts-wqy-zenhei
#linux字型路徑
#font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
student1:dict[str,int] = {"國文":75,"英文":80,"數學":90,"歷史":85,"探索":76}
student2:dict[str,int] = {"國文":74,"英文":90,"數學":91,"歷史":86,"探索":60}
subject = list(student1.keys())
scorel = list(student1.values())
score2 = list(student2.values())

figure = plt.figure(figsize=(10,5))
axes = figure.add_subplot(1,1,1)
axes.plot(subject,scorel,"co-.",label="學生1")
axes.plot(subject,score2,"bo-.",label="學生2")
axes.set_xticklabels(subject,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
axes.grid(axis='y')
x_location = axes.get_xticks()
for x in y_location:
    axes.annotate(str(scorel[x]),(x+0.05,scorel[x]))
    axes.annotate(str(score2[x]),(x+0.05,score2[x]))
plt.show()
# Out:
# /tmp/ipykernel_11305/2525861419.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subject,fontproperties=font)
